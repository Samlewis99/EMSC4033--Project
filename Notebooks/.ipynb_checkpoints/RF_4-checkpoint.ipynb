# %% [markdown]
# # Evaluate model and improve accuracy
#
# This process is called tuning in machine learning. It is one of the most important stages in making sure our model doesnt overfit data, or underfit data. We evaluate how the model performs by testing it on unseen data and can infer if we need to simplify our model (ie removing outliers or uneccesary features) or adding in more variables if its is over simplified.
#
# We have now run our random forests from a random starting point with all of our variables. We can see however that not all of our variables are significant in the classification we are trying to make. We will drop the sepal width variable and re-run our random forest algorithm.

# %%
#call data in from previous notebook
from Functions_r import f_rf as ft
data = ft.get_data()

# %% [markdown]
# ## Generate the model with selected features
# Look back to the RF_2 notebook to see how we split the data and load variables in. Remember this time we want to leave 'sepal width' out of our model.
#
# You can call the fucntion ```Accuracy_test``` to see if your results match up with the correct results. *Don't worry if your results don't exactly match up, as it is randomized strating points and samples we wont ever get exactly the same result.*

# %%
#Try it here

# %%
ft.Accuracy_test()
# Out:
# Accuracy: 0.9555555555555556

# %% [markdown]
# # Plotting our predictions
# Using our new model we can plot our predicted values as we did previously for the actual values. Try it out and see if the species predictions seem to be correct!

# %%
from sklearn.model_selection import train_test_split
X=data[['sepal length', 'sepal width', 'petal length']]  # Features
y=data['species']  # Labels

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) # 30% training and 70% test
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train,y_train)

# prediction on test set
y_pred=clf.predict(X_test)

# %%
## Plotting the actual values
from sklearn.datasets import load_iris
iris = load_iris()

from matplotlib import pyplot as plt

# The indices of the features that we are plotting
x_index = 0
y_index = 1

# this formatter will label the colorbar with the correct target names
formatter = plt.FuncFormatter(lambda i, *args: iris.target_names[int(i)])

plt.figure(figsize=(5, 4))
plt.scatter(iris.data[:, x_index], iris.data[:, y_index], c=iris.target)
plt.colorbar(ticks=[0, 1, 2], format=formatter)
plt.xlabel(iris.feature_names[x_index])
plt.ylabel(iris.feature_names[y_index])

plt.tight_layout()
plt.show()

# %%
#Plotting our predicted test values
from sklearn.datasets import load_iris
iris = X_test

from matplotlib import pyplot as plt

# The indices of the features that we are plotting
x_index = iris['sepal length']
y_index = iris['sepal width']

# this formatter will label the colorbar with the correct target names
#formatter = plt.FuncFormatter(lambda i, *args: y_pred[int(i)])

plt.figure(figsize=(5, 4))
plt.scatter(x_index, y_index, c=y_pred)
plt.colorbar(ticks=[0, 1, 2],)
plt.xlabel('sepal length')
plt.ylabel('sepal width')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Try random forests yourself
#
# We have now run through a full example of how random forests work. Try implement this machine learning algorithm on some of your own data. *Hint* If you don't have any of your own data you can try this out with the NOAA (temps) data that we did a one-hot encoding on.
#
# If you try it on this data, you will need subsitute the random forest classifer for the random forest regressor function.
